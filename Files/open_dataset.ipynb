# %%
from nilearn import plotting
import nibabel as nib
# %matplotlib inline

# %%
img = nib.load('/home/mh/mywork/covid19/covid_segment_dataset/tr_im.nii')
mask = nib.load('/home/mh/mywork/covid19/covid_segment_dataset/tr_mask.nii')

# %%
print(img.shape)
print(mask.shape)
# Out:
# (512, 512, 100)
# (512, 512, 100)

# %%
plotting.plot_img(img)

# %%
plotting.plot_img(mask)
